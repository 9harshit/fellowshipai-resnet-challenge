# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# # Importing Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

# %% [markdown]
# # Creating Data Transform Object
#
# - Resizing Image
# - Applying random Horizontal flip
# - Converting image to Tensor
# - Normalizing data

# %%
mean = np.array([0.5, 0.5, 0.5])
std = np.array([0.25, 0.25, 0.25])

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
}

# %% [markdown]
# # Preprocessing Data
#
# - Importing dataset
# - Applying transformation on data using data_transform object

# %%
data_dir = '/content/gdrive/MyDrive/flower_dataset'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=0)
              for x in ['train', "val"]}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', "val"]}
class_names = image_datasets['train'].classes

print(len(class_names), (dataset_sizes["train"]))
# Out:
# 102 1020

# %% [markdown]
# # Selecting Device
#
# - Device will be set as GPU if GPU is present.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
def imshow(inp, title):

    """Imshow for Tensor"""
    
    inp = inp.numpy().transpose((1, 2, 0))
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    plt.title(title)
    plt.show()

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

#DIsplaying images
imshow(out, title=[class_names[x] for x in classes])

# %%
# Creating variables to plot accuracy diagram
list_loss, list_acc, list_val_acc, list_val_loss = [], [], [], []

# %% [markdown]
# # Model Training Loop

# %%
def train_model(model, criterion, optimizer, scheduler, dlr = False,num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()

                # calculating loss and prediction accuracy of each input and adding it
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if dlr:
              if phase == 'train':
                  scheduler.step()

            # Calculation Loss and accuracy for the epoch
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # Storing model Accuracy and loss for plotting diagram
            if phase == "train":
              list_acc2.append(epoch_acc)
              list_loss2.append(epoch_loss)
            else:
              list_val_acc2.append(epoch_acc)
              list_val_loss2.append(epoch_loss)

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    # Printing time elapsed during training
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    
    # Printing best Accuracy achieved during training
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# # Creating model
#
# - Importing pretrained model
# - Freezing pretained weights
# - Creating Custom layer
# - Setting hyperparameters

# %%
# Load a pretrained model and reset final fully connected layer.
model = models.resnet18(pretrained=True)

# Freezing pretrained weights and parameters
for param in model.parameters():
    param.requires_grad = False

# Getting model features
num_ftrs = model.fc.in_features

# Creating custom linear dense layer for output
# Here the size of each output sample is set to 102.
model.fc = nn.Linear(num_ftrs,  len(class_names))

# Passing model to the device
model = model.to(device)

# Cross Entropy as loss function
criterion = nn.CrossEntropyLoss()

# Adam opmtimzer is selected with learning rate as 0.001
optimizer = optim.Adam(model.parameters(), lr=0.001)

# StepLR Decays the learning rate of each parameter group by gamma every step_size epochs
# Decay LR by a factor of 0.005 every 10 epochs
# Learning rate scheduling should be applied after optimizer’s update
step_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.005)

# %% [markdown]
# # Training model
#
# - If dlr is true, weight decay is activated, by default set to False

# %%
model = train_model(model, criterion, optimizer, step_lr_scheduler, dlr = True,num_epochs=100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 3.4775 Acc: 0.2039
# val Loss: 2.1681 Acc: 0.5029
#
# Epoch 1/99
# ----------
# train Loss: 2.7517 Acc: 0.3696
# val Loss: 1.7589 Acc: 0.5941
#
# Epoch 2/99
# ----------
# train Loss: 2.3483 Acc: 0.4520
# val Loss: 1.5378 Acc: 0.6157
#
# Epoch 3/99
# ----------
# train Loss: 2.0394 Acc: 0.5216
# val Loss: 1.1959 Acc: 0.6951
#
# Epoch 4/99
# ----------
# train Loss: 1.7139 Acc: 0.6059
# val Loss: 1.0180 Acc: 0.7461
#
# Epoch 5/99
# ----------
# train Loss: 1.6014 Acc: 0.6118
# val Loss: 0.9584 Acc: 0.7608
#
# Epoch 6/99
# ----------
# train Loss: 1.4111 Acc: 0.6873
# val Loss: 0.9391 Acc: 0.7431
#
# Epoch 7/99
# ----------
# train Loss: 1.3864 Acc: 0.6657
# val Loss: 0.8498 Acc: 0.7637
#
# Epoch 8/99
# ----------
# train Loss: 1.2987 Acc: 0.6843
# val Loss: 0.8062 Acc: 0.7667
#
# Epoch 9/99
# ----------
# train Loss: 1.1652 Acc: 0.7284
# val Loss: 0.8027 Acc: 0.7755
#
# Epoch 10/99
# ----------
# train Loss: 1.1259 Acc: 0.7324
# val Loss: 0.7502 Acc: 0.7971
#
# Epoch 11/99
# ----------
# train Loss: 1.1189 Acc: 0.7451
# val Loss: 0.7341 Acc: 0.7863
#
# Epoch 12/99
# ----------
# train Loss: 1.0693 Acc: 0.7696
# val Loss: 0.7932 Acc: 0.7784
#
# Epoch 13/99
# ----------
# train Loss: 1.0828 Acc: 0.7441
# val Loss: 0.6670 Acc: 0.8147
#
# Epoch 14/99
# ----------
# train Loss: 1.0409 Acc: 0.7647
# val Loss: 0.7125 Acc: 0.8088
#
# Epoch 15/99
# ----------
# train Loss: 1.0487 Acc: 0.7794
# val Loss: 0.7123 Acc: 0.8029
#
# Epoch 16/99
# ----------
# train Loss: 0.9845 Acc: 0.8020
# val Loss: 0.7021 Acc: 0.8127
#
# Epoch 17/99
# ----------
# train Loss: 0.9231 Acc: 0.8137
# val Loss: 0.6508 Acc: 0.8206
#
# Epoch 18/99
# ----------
# train Loss: 0.9875 Acc: 0.7853
# val Loss: 0.6583 Acc: 0.8176
#
# Epoch 19/99
# ----------
# train Loss: 0.9486 Acc: 0.8039
# val Loss: 0.6715 Acc: 0.8176
#
# Epoch 20/99
# ----------
# train Loss: 0.9699 Acc: 0.7912
# val Loss: 0.6797 Acc: 0.8137
#
# Epoch 21/99
# ----------
# train Loss: 0.9209 Acc: 0.8127
# val Loss: 0.6814 Acc: 0.8245
#
# Epoch 22/99
# ----------
# train Loss: 1.0100 Acc: 0.7814
# val Loss: 0.6993 Acc: 0.8098
#
# Epoch 23/99
# ----------
# train Loss: 0.9542 Acc: 0.8108
# val Loss: 0.6521 Acc: 0.8196
#
# Epoch 24/99
# ----------
# train Loss: 0.9927 Acc: 0.7931
# val Loss: 0.6735 Acc: 0.8186
#
# Epoch 25/99
# ----------
# train Loss: 0.9318 Acc: 0.7961
# val Loss: 0.6584 Acc: 0.8245
#
# Epoch 26/99
# ----------
# train Loss: 0.9683 Acc: 0.8127
# val Loss: 0.6727 Acc: 0.8118
#
# Epoch 27/99
# ----------
# train Loss: 0.9926 Acc: 0.7824
# val Loss: 0.6548 Acc: 0.8255
#
# Epoch 28/99
# ----------
# train Loss: 0.9631 Acc: 0.7892
# val Loss: 0.6925 Acc: 0.8098
#
# Epoch 29/99
# ----------
# train Loss: 0.9430 Acc: 0.7990
# val Loss: 0.6956 Acc: 0.8127
#
# Epoch 30/99
# ----------
# train Loss: 1.0417 Acc: 0.7931
# val Loss: 0.6597 Acc: 0.8216
#
# Epoch 31/99
# ----------
# train Loss: 1.0051 Acc: 0.7863
# val Loss: 0.6870 Acc: 0.8127
#
# Epoch 32/99
# ----------
# train Loss: 0.9274 Acc: 0.8127
# val Loss: 0.6849 Acc: 0.8157
#
# Epoch 33/99
# ----------
# train Loss: 0.9925 Acc: 0.7902
# val Loss: 0.7039 Acc: 0.8127
#
# Epoch 34/99
# ----------
# train Loss: 0.9620 Acc: 0.8039
# val Loss: 0.6907 Acc: 0.8137
#
# Epoch 35/99
# ----------
# train Loss: 0.9789 Acc: 0.8147
# val Loss: 0.6874 Acc: 0.8118
#
# Epoch 36/99
# ----------
# train Loss: 0.9768 Acc: 0.8020
# val Loss: 0.6445 Acc: 0.8265
#
# Epoch 37/99
# ----------
# train Loss: 0.9642 Acc: 0.8010
# val Loss: 0.6551 Acc: 0.8167
#
# Epoch 38/99
# ----------
# train Loss: 0.9734 Acc: 0.7990
# val Loss: 0.6473 Acc: 0.8284
#
# Epoch 39/99
# ----------
# train Loss: 0.9621 Acc: 0.8029
# val Loss: 0.6325 Acc: 0.8324
#
# Epoch 40/99
# ----------
# train Loss: 0.9370 Acc: 0.8167
# val Loss: 0.7042 Acc: 0.8098
#
# Epoch 41/99
# ----------
# train Loss: 0.9911 Acc: 0.7922
# val Loss: 0.6595 Acc: 0.8118
#
# Epoch 42/99
# ----------
# train Loss: 0.9326 Acc: 0.8127
# val Loss: 0.6723 Acc: 0.8118
#
# Epoch 43/99
# ----------
# train Loss: 0.9422 Acc: 0.8049
# val Loss: 0.6675 Acc: 0.8206
#
# Epoch 44/99
# ----------
# train Loss: 1.0128 Acc: 0.7882
# val Loss: 0.6773 Acc: 0.8118
#
# Epoch 45/99
# ----------
# train Loss: 0.9171 Acc: 0.8088
# val Loss: 0.6579 Acc: 0.8265
#
# Epoch 46/99
# ----------
# train Loss: 0.9015 Acc: 0.8235
# val Loss: 0.6515 Acc: 0.8235
#
# Epoch 47/99
# ----------
# train Loss: 0.9499 Acc: 0.8078
# val Loss: 0.6780 Acc: 0.8147
#
# Epoch 48/99
# ----------
# train Loss: 0.9695 Acc: 0.8049
# val Loss: 0.6793 Acc: 0.8137
#
# Epoch 49/99
# ----------
# train Loss: 0.9293 Acc: 0.8039
# val Loss: 0.6581 Acc: 0.8275
#
# Epoch 50/99
# ----------
# train Loss: 0.9844 Acc: 0.8069
# val Loss: 0.6802 Acc: 0.8157
#
# Epoch 51/99
# ----------
# train Loss: 1.0122 Acc: 0.7971
# val Loss: 0.6697 Acc: 0.8137
#
# Epoch 52/99
# ----------
# train Loss: 0.9784 Acc: 0.8049
# val Loss: 0.6858 Acc: 0.8147
#
# Epoch 53/99
# ----------
# train Loss: 0.9886 Acc: 0.7892
# val Loss: 0.6901 Acc: 0.8127
#
# Epoch 54/99
# ----------
# train Loss: 0.9771 Acc: 0.7863
# val Loss: 0.6564 Acc: 0.8245
#
# Epoch 55/99
# ----------
# train Loss: 0.9696 Acc: 0.8049
# val Loss: 0.6590 Acc: 0.8167
#
# Epoch 56/99
# ----------
# train Loss: 0.9343 Acc: 0.8127
# val Loss: 0.6969 Acc: 0.8059
#
# Epoch 57/99
# ----------
# train Loss: 1.0005 Acc: 0.7882
# val Loss: 0.6567 Acc: 0.8304
#
# Epoch 58/99
# ----------
# train Loss: 0.9611 Acc: 0.7980
# val Loss: 0.6935 Acc: 0.8147
#
# Epoch 59/99
# ----------
# train Loss: 1.0079 Acc: 0.7833
# val Loss: 0.6755 Acc: 0.8167
#
# Epoch 60/99
# ----------
# train Loss: 0.9837 Acc: 0.8069
# val Loss: 0.6935 Acc: 0.8127
#
# Epoch 61/99
# ----------
# train Loss: 0.9446 Acc: 0.8127
# val Loss: 0.6586 Acc: 0.8206
#
# Epoch 62/99
# ----------
# train Loss: 0.9290 Acc: 0.8157
# val Loss: 0.6661 Acc: 0.8157
#
# Epoch 63/99
# ----------
# train Loss: 0.9267 Acc: 0.8216
# val Loss: 0.6395 Acc: 0.8206
#
# Epoch 64/99
# ----------
# train Loss: 0.9957 Acc: 0.7824
# val Loss: 0.6514 Acc: 0.8255
#
# Epoch 65/99
# ----------
# train Loss: 0.9461 Acc: 0.8235
# val Loss: 0.6641 Acc: 0.8078
#
# Epoch 66/99
# ----------
# train Loss: 1.0254 Acc: 0.7843
# val Loss: 0.6917 Acc: 0.8127
#
# Epoch 67/99
# ----------
# train Loss: 0.9423 Acc: 0.8049
# val Loss: 0.6659 Acc: 0.8167
#
# Epoch 68/99
# ----------
# train Loss: 0.9291 Acc: 0.8108
# val Loss: 0.6633 Acc: 0.8225
#
# Epoch 69/99
# ----------
# train Loss: 1.0037 Acc: 0.7814
# val Loss: 0.6597 Acc: 0.8147
#
# Epoch 70/99
# ----------
# train Loss: 0.9387 Acc: 0.8059
# val Loss: 0.6708 Acc: 0.8118
#
# Epoch 71/99
# ----------
# train Loss: 0.9987 Acc: 0.7990
# val Loss: 0.6623 Acc: 0.8176
#
# Epoch 72/99
# ----------
# train Loss: 1.0035 Acc: 0.7931
# val Loss: 0.6465 Acc: 0.8245
#
# Epoch 73/99
# ----------
# train Loss: 0.9549 Acc: 0.8049
# val Loss: 0.6635 Acc: 0.8176
#
# Epoch 74/99
# ----------
# train Loss: 0.9686 Acc: 0.7863
# val Loss: 0.6558 Acc: 0.8265
#
# Epoch 75/99
# ----------
# train Loss: 1.0566 Acc: 0.7745
# val Loss: 0.6790 Acc: 0.8127
#
# Epoch 76/99
# ----------
# train Loss: 0.9707 Acc: 0.8127
# val Loss: 0.6585 Acc: 0.8206
#
# Epoch 77/99
# ----------
# train Loss: 0.9397 Acc: 0.8029
# val Loss: 0.6746 Acc: 0.8176
#
# Epoch 78/99
# ----------
# train Loss: 0.9694 Acc: 0.7892
# val Loss: 0.6873 Acc: 0.8049
#
# Epoch 79/99
# ----------
# train Loss: 0.9655 Acc: 0.8059
# val Loss: 0.6785 Acc: 0.8216
#
# Epoch 80/99
# ----------
# train Loss: 0.9742 Acc: 0.8098
# val Loss: 0.6811 Acc: 0.8167
#
# Epoch 81/99
# ----------
# train Loss: 0.9398 Acc: 0.7922
# val Loss: 0.6690 Acc: 0.8186
#
# Epoch 82/99
# ----------
# train Loss: 0.9407 Acc: 0.8059
# val Loss: 0.6726 Acc: 0.8176
#
# Epoch 83/99
# ----------
# train Loss: 0.9608 Acc: 0.7941
# val Loss: 0.6806 Acc: 0.8108
#
# Epoch 84/99
# ----------
# train Loss: 0.9638 Acc: 0.8098
# val Loss: 0.6727 Acc: 0.8176
#
# Epoch 85/99
# ----------
# train Loss: 0.9837 Acc: 0.8059
# val Loss: 0.6834 Acc: 0.8157
#
# Epoch 86/99
# ----------
# train Loss: 0.9739 Acc: 0.7961
# val Loss: 0.6775 Acc: 0.8098
#
# Epoch 87/99
# ----------
# train Loss: 1.0202 Acc: 0.7873
# val Loss: 0.6569 Acc: 0.8167
#
# Epoch 88/99
# ----------
# train Loss: 0.9893 Acc: 0.8000
# val Loss: 0.6619 Acc: 0.8216
#
# Epoch 89/99
# ----------
# train Loss: 0.9975 Acc: 0.7912
# val Loss: 0.6740 Acc: 0.8108
#
# Epoch 90/99
# ----------
# train Loss: 0.9117 Acc: 0.8265
# val Loss: 0.6705 Acc: 0.8206
#
# Epoch 91/99
# ----------
# train Loss: 0.9915 Acc: 0.8000
# val Loss: 0.6516 Acc: 0.8216
#
# Epoch 92/99
# ----------
# train Loss: 0.9722 Acc: 0.8029
# val Loss: 0.6705 Acc: 0.8255
#
# Epoch 93/99
# ----------
# train Loss: 0.9881 Acc: 0.7971
# val Loss: 0.6476 Acc: 0.8255
#
# Epoch 94/99
# ----------
# train Loss: 0.9661 Acc: 0.8039
# val Loss: 0.6842 Acc: 0.8137
#
# Epoch 95/99
# ----------
# train Loss: 0.9233 Acc: 0.8186
# val Loss: 0.6478 Acc: 0.8245
#
# Epoch 96/99
# ----------
# train Loss: 1.0075 Acc: 0.7804
# val Loss: 0.6680 Acc: 0.8284
#
# Epoch 97/99
# ----------
# train Loss: 0.9690 Acc: 0.8020
# val Loss: 0.6629 Acc: 0.8216
#
# Epoch 98/99
# ----------
# train Loss: 0.9406 Acc: 0.8108
# val Loss: 0.6537 Acc: 0.8216
#
# Epoch 99/99
# ----------
# train Loss: 0.9530 Acc: 0.8108
# val Loss: 0.6617 Acc: 0.8275
#
# Training complete in 52m 10s
# Best val Acc: 0.832353

# %% [markdown]
# # Saving Model

# %%
torch.save(model_basic.state_dict(), "/content/sample_data/model_dlr")

# %% [markdown]
# # Plotting accuracy diagram

# %%
import matplotlib.pyplot as plt

plt.plot(list_acc)
plt.plot(list_val_acc)
plt.plot(list_loss)
plt.plot(list_val_loss)
plt.title('model accuracy')
plt.ylabel('Values')
plt.xlabel('Epoch')
plt.legend(['Accuracy', 'Validation Accuracy', "Loss", "Validation Loss"], loc='upper right')
plt.show()
